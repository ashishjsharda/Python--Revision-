# %%
# Install only the working ones first:
# !pip install gtts edge-tts librosa soundfile
# !apt-get install -y espeak espeak-data

# Test without PyAudio:
from gtts import gTTS
import librosa
print("Core libraries installed!")
# Out:
# ...
#   Using cached gTTS-2.5.4-py3-none-any.whl.metadata (4.1 kB)
# ...
#   Using cached edge_tts-7.0.2-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached srt-3.5.3-py3-none-any.whl
# ...
# Using cached gTTS-2.5.4-py3-none-any.whl (29 kB)
# Using cached edge_tts-7.0.2-py3-none-any.whl (26 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libespeak1 libsonic0
# The following NEW packages will be installed:
#   espeak espeak-data libespeak1 libsonic0
# 0 upgraded, 4 newly installed, 0 to remove and 35 not upgraded.
# Need to get 1,316 kB of archives.
# ...

# %%
from gtts import gTTS
tts = gTTS("Hello, this is a Colab text to speech demo!")
tts.save("demo.mp3")

# %%
from IPython.display import Audio
Audio("demo.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install edge-tts
import edge_tts
import asyncio

communicate = edge_tts.Communicate("Hello from Edge TTS!", "en-US-GuyNeural")
await communicate.save("edge.mp3")

from IPython.display import Audio
Audio("edge.mp3")
# Out:
# ...
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
